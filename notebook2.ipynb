# %%
df =spark.read.csv('/Volumes/catalog1/default/volume1/retail_project_sample_data/audit_logs.csv', header=True)

display(df)

# %%
df1 = df.filter(df.pipeline_status == "Pending").select("pipeline_id", "execution_start_time", "execution_end_time")

display(df1)
